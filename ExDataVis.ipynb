# %% [markdown]
# <a href="https://colab.research.google.com/github/frag30041997/jupyter-one/blob/master/ExDataVis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone http://github.com/frag30041997/jupyter-one.git
# Out:
# Cloning into 'jupyter-one'...
# fatal: could not read Username for 'https://github.com': No such device or address

# %%
##Essai git changement

# %% [markdown]
# # import

# %%
import numpy as np, seaborn as sns, pandas as pd, matplotlib.pyplot as plt

# %% [markdown]
# ## EX 1

# %%
df = pd.read_csv('/house_pricing.csv')

# %%
df
# Out:
#         Id  MSSubClass MSZoning  ...  SaleType  SaleCondition SalePrice
# 0        1          60       RL  ...        WD         Normal    208500
# 1        2          20       RL  ...        WD         Normal    181500
# 2        3          60       RL  ...        WD         Normal    223500
# 3        4          70       RL  ...        WD        Abnorml    140000
# 4        5          60       RL  ...        WD         Normal    250000
# ...    ...         ...      ...  ...       ...            ...       ...
# 1455  1456          60       RL  ...        WD         Normal    175000
# 1456  1457          20       RL  ...        WD         Normal    210000
# 1457  1458          70       RL  ...        WD         Normal    266500
# 1458  1459          20       RL  ...        WD         Normal    142125
# 1459  1460          20       RL  ...        WD         Normal    147500
#
# [1460 rows x 81 columns]

# %%
df.dtypes
# Out:
# Id                 int64
# MSSubClass         int64
# MSZoning          object
# LotFrontage      float64
# LotArea            int64
#                   ...
# MoSold             int64
# YrSold             int64
# SaleType          object
# SaleCondition     object
# SalePrice          int64
# Length: 81, dtype: object

# %%
plt.scatter(x='LotArea', y='SalePrice')

# %%
df.plot.scatter(x='LotArea', y='SalePrice')

# %%
df[(df['LotArea'] < 20000) & (df['SalePrice'] < 500000)].plot.scatter(x='LotArea', y='SalePrice')

# %%
df.plot.scatter(x='LotArea', y='LotFrontage')

# %%
df[(df['LotArea'] < 100000) & (df['LotFrontage'] < 200)].plot.scatter(x='LotArea', y='LotFrontage')

# %% [markdown]
# ## EX 2

# %%
df2 = pd.read_csv('sample_data/sales_predictions.csv')

# %%
df2
# Out:
#               date  date_block_num  shop_id  item_id  item_price  item_cnt_day
# 0       02.01.2013               0       59  22154.0      999.00           1.0
# 1       03.01.2013               0       25   2552.0      899.00           1.0
# 2       05.01.2013               0       25   2552.0      899.00          -1.0
# 3       06.01.2013               0       25   2554.0     1709.05           1.0
# 4       15.01.2013               0       25   2555.0     1099.00           1.0
# ...            ...             ...      ...      ...         ...           ...
# 399866  28.04.2013               3       57  19153.0      349.00           1.0
# 399867  30.04.2013               3       57  19154.0      199.00           1.0
# 399868  09.04.2013               3       57  19164.0      399.00           1.0
# 399869  11.04.2013               3       57  19164.0      399.00           2.0
# 399870  12.04.2013               3       57      NaN         NaN           NaN
#
# ...
