# %% [markdown]
# <a href="https://colab.research.google.com/github/frag30041997/jupyter-one/blob/master/Expose.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# \>[Dataset](https://www.kaggle.com/bobbyscience/league-of-legends-diamond-ranked-games-10-min)<

# %%
import numpy as np, seaborn as sns, pandas as pd, matplotlib.pyplot as plt
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)

# %%
df = pd.read_csv('/content/drive/My Drive/Colab Notebooks/high_diamond_ranked_10min.csv',encoding="ISO-8859-1",engine='python')

# %%
df.head()
# Out:
#        gameId  blueWins  blueWardsPlaced  blueWardsDestroyed  blueFirstBlood  blueKills  blueDeaths  blueAssists  blueEliteMonsters  blueDragons  blueHeralds  blueTowersDestroyed  blueTotalGold  blueAvgLevel  blueTotalExperience  blueTotalMinionsKilled  blueTotalJungleMinionsKilled  blueGoldDiff  blueExperienceDiff  blueCSPerMin  blueGoldPerMin  redWardsPlaced  redWardsDestroyed  redFirstBlood  redKills  redDeaths  redAssists  redEliteMonsters  redDragons  redHeralds  redTowersDestroyed  redTotalGold  redAvgLevel  redTotalExperience  redTotalMinionsKilled  redTotalJungleMinionsKilled  redGoldDiff  redExperienceDiff  redCSPerMin  redGoldPerMin
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9879 entries, 0 to 9878
# Data columns (total 40 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   gameId                        9879 non-null   int64
#  1   blueWins                      9879 non-null   int64
#  2   blueWardsPlaced               9879 non-null   int64
#  3   blueWardsDestroyed            9879 non-null   int64
#  4   blueFirstBlood                9879 non-null   int64
#  5   blueKills                     9879 non-null   int64
#  6   blueDeaths                    9879 non-null   int64
#  7   blueAssists                   9879 non-null   int64
#  8   blueEliteMonsters             9879 non-null   int64
#  9   blueDragons                   9879 non-null   int64
#  10  blueHeralds                   9879 non-null   int64
#  11  blueTowersDestroyed           9879 non-null   int64
#  12  blueTotalGold                 9879 non-null   int64
# ...

# %%
heat = sns.heatmap(df.corr(),annot=True)

# %%
df_a = df.drop(['blueWardsDestroyed','redWardsDestroyed','blueAvgLevel','redAvgLevel','redTotalExperience','redHeralds','redTotalMinionsKilled','redTowersDestroyed','redTotalGold','redGoldDiff','redCSPerMin','redExperienceDiff','redGoldPerMin','redTotalMinionsKilled','redTotalJungleMinionsKilled'], axis=1)

# %%
df_a.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9879 entries, 0 to 9878
# Data columns (total 26 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   gameId                        9879 non-null   int64
#  1   blueWins                      9879 non-null   int64
#  2   blueWardsPlaced               9879 non-null   int64
#  3   blueFirstBlood                9879 non-null   int64
#  4   blueKills                     9879 non-null   int64
#  5   blueDeaths                    9879 non-null   int64
#  6   blueAssists                   9879 non-null   int64
#  7   blueEliteMonsters             9879 non-null   int64
#  8   blueDragons                   9879 non-null   int64
#  9   blueHeralds                   9879 non-null   int64
#  10  blueTowersDestroyed           9879 non-null   int64
#  11  blueTotalGold                 9879 non-null   int64
#  12  blueTotalExperience           9879 non-null   int64
# ...

# %%
plt.figure(figsize = (25,22))
heat = sns.heatmap(df.corr(),annot=True,cmap="Blues")

# %%
plt.figure(figsize = (25,22))

heat = sns.heatmap(df_a.corr(),annot=True,cmap="Blues")

# %%
df.describe()

# %% [markdown]
# 49.9% win blue

# %%
g = sns.catplot(x="blueWins", y="blueKills", kind='bar' ,data=df)

# %%
g = sns.catplot(x="blueWins", y="blueDeaths", kind='bar' ,data=df)

# %%
g = sns.catplot(x="blueWins", y="blueTotalGold", kind='bar' ,data=df.sample(300))

# %%
df.plot.scatter(x='blueKills', y='blueCSPerMin')
g = sns.catplot(x="blueKills", y="blueCSPerMin", kind='bar' , color='#99C' ,data=df)

# %%
plt.figure(figsize = (25,22))
heat = sns.heatmap(df_a,annot=True,pivot)
# Out:
#   File "<ipython-input-22-7c194970234c>", line 2
#     heat = sns.heatmap(df_a,annot=True,pivot)
#                                       ^
# SyntaxError: positional argument follows keyword argument

# %%
df.plot.scatter(x='blueTotalMinionsKilled', y='blueTotalGold')

# %%
g = sns.boxplot(x="blueWins", y="blueTotalGold", data=df)

# %%
g = sns.boxplot(x="blueWins", y="blueTotalGold", data=df[(df['blueTotalGold'] < 18500) 
& (df['blueTotalGold'] > 13500)])

# %%
j = sns.lmplot(x="blueTotalGold", y="blueTotalMinionsKilled", data=df.sample(300))

# %%
j = sns.lmplot(x="blueTotalGold", y="blueTotalJungleMinionsKilled", data=df.sample(300))

# %%
j = sns.lmplot(x="blueDragons", y="blueTotalGold", data=df.sample(300))

# %%
j = sns.lmplot(x="blueKills", y="blueTotalGold", data=df.sample(300))

# %%
j = sns.lmplot(x="blueWins", y="blueDragons", data=df.sample(300))

# %%
j = sns.lmplot(x="blueWins", y="blueKills", data=df.sample(300))

# %%
j = sns.lmplot(x="blueTotalMinionsKilled", y="blueWins", data=df.sample(300))
